# %%
# Import packages
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier

# Import data and format data, initialize variables
X = pd.read_csv('x_train__wo_outlier_KNN.csv',delimiter=',', index_col='id')
ydata = pd.read_csv('y_train_wo_outlier.csv',delimiter=',', index_col='id')

X_test = pd.read_csv('x_test_KNN.csv',delimiter=',', index_col='id')

y=ydata['y']

num_features=200

# %%
#Pearson Correlation
def Cor_selector(X, y,num_features):
    print("Cor")
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_features:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
#Chi squared test
def Chi_selector(X,y,num_features):
    print("Chi")
    #Normalize values as required for Chi2 test
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num_features)
    chi_selector.fit(X_norm, y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    return chi_support, chi_feature

# %%
#Recursive Feature Elimination
def RFE_selector(X,y,num_features):
    X_norm = MinMaxScaler().fit_transform(X)
    #max_iter bumped up to 2000 in order to converge (1000 default too small)
    rfe_selector = RFE(estimator=LogisticRegression(max_iter=2000), n_features_to_select=num_features, step=10, verbose=5)
    rfe_selector.fit(X_norm, y)
    rfe_support = rfe_selector.get_support()
    rfe_feature = X.loc[:,rfe_support].columns.tolist()
    return rfe_support, rfe_feature

# %%
#Lasso : SelectFromModel (L1 norm)
def LassoModel(X,y,num_features):
    print("Lasso")
    X_norm = MinMaxScaler().fit_transform(X)
    embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l1",solver='liblinear'), max_features=num_features)
    embeded_lr_selector.fit(X_norm, y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    return embeded_lr_support, embeded_lr_feature

# %%
#Tree-based : SelectFromModel
def TreebasedModel(X,y,num_features):
    print("TBM")
    embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=num_features)
    embeded_rf_selector.fit(X, y)
    embeded_rf_support = embeded_rf_selector.get_support()
    embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    return embeded_rf_support, embeded_rf_feature

# %%
#LightGBM
def LightGBM(X,y,num_features):
    print("GBM")
    lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)
    embeded_lgb_selector = SelectFromModel(lgbc, max_features=num_features)
    embeded_lgb_selector.fit(X, y)
    embeded_lgb_support = embeded_lgb_selector.get_support()
    embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
    return embeded_lgb_support, embeded_lgb_feature

# %%
#MAIN
pd.set_option('display.max_rows', 250)
feature_name = X.columns.tolist()

#Initialize variables corresponding to respective tests
cor_support,_ = Cor_selector(X, y,num_features)
chi_support,_ = Chi_selector(X,y,num_features)
rfe_support,_ = RFE_selector(X,y,num_features)
embeded_lr_support,_ = LassoModel(X,y,num_features)
embeded_rf_support,_ = TreebasedModel(X,y,num_features)
embeded_lgb_support,_ = LightGBM(X,y,num_features)

# put all selection together
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 'Logistics':embeded_lr_support,
                                    'Random Forest':embeded_rf_support, 'LightGBM':embeded_lgb_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(num_features)
#Count the selected times for each feature and sorts them
# Out:
# Cor
# Chi
# Fitting estimator with 832 features.
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# Fitting estimator with 822 features.
# Fitting estimator with 812 features.
# Fitting estimator with 802 features.
# Fitting estimator with 792 features.
# Fitting estimator with 782 features.
# Fitting estimator with 772 features.
# Fitting estimator with 762 features.
# Fitting estimator with 752 features.
# Fitting estimator with 742 features.
# Fitting estimator with 732 features.
# Fitting estimator with 722 features.
# Fitting estimator with 712 features.
# Fitting estimator with 702 features.
# Fitting estimator with 692 features.
# Fitting estimator with 682 features.
# Fitting estimator with 672 features.
# Fitting estimator with 662 features.
# Fitting estimator with 652 features.
# Fitting estimator with 642 features.
# Fitting estimator with 632 features.
# Fitting estimator with 622 features.
# Fitting estimator with 612 features.
# Fitting estimator with 602 features.
# Fitting estimator with 592 features.
# Fitting estimator with 582 features.
# Fitting estimator with 572 features.
# Fitting estimator with 562 features.
# Fitting estimator with 552 features.
# Fitting estimator with 542 features.
# Fitting estimator with 532 features.
# Fitting estimator with 522 features.
# Fitting estimator with 512 features.
# Fitting estimator with 502 features.
# Fitting estimator with 492 features.
# Fitting estimator with 482 features.
# Fitting estimator with 472 features.
# Fitting estimator with 462 features.
# Fitting estimator with 452 features.
# Fitting estimator with 442 features.
# Fitting estimator with 432 features.
# Fitting estimator with 422 features.
# Fitting estimator with 412 features.
# Fitting estimator with 402 features.
# Fitting estimator with 392 features.
# Fitting estimator with 382 features.
# Fitting estimator with 372 features.
# Fitting estimator with 362 features.
# Fitting estimator with 352 features.
# Fitting estimator with 342 features.
# Fitting estimator with 332 features.
# Fitting estimator with 322 features.
# Fitting estimator with 312 features.
# Fitting estimator with 302 features.
# Fitting estimator with 292 features.
# Fitting estimator with 282 features.
# Fitting estimator with 272 features.
# Fitting estimator with 262 features.
# Fitting estimator with 252 features.
# Fitting estimator with 242 features.
# Fitting estimator with 232 features.
# Fitting estimator with 222 features.
# Fitting estimator with 212 features.
# Fitting estimator with 202 features.
# Lasso
# TBM
# GBM
#     Feature  Pearson  Chi-2    RFE  Logistics  Random Forest  LightGBM  Total
# 1       x96    False   True   True       True           True      True      5
# 2       x85     True   True   True      False           True      True      5
# 3      x785     True   True   True       True           True     False      5
# 4       x58    False   True   True       True           True      True      5
# 5       x53    False   True   True       True           True      True      5
# 6      x457     True   True   True       True           True     False      5
# 7       x27    False   True   True       True           True      True      5
# 8       x26    False   True   True       True           True      True      5
# 9      x186    False   True   True       True           True      True      5
# 10     x136    False   True   True       True           True      True      5
# 11     x134    False   True   True       True           True      True      5
# 12     x122    False   True   True       True           True      True      5
# 13     x102     True   True   True       True          False      True      5
# 14       x9    False   True   True       True          False      True      4
# 15      x87    False   True   True      False           True      True      4
# 16      x84    False   True   True       True          False      True      4
# 17      x83    False   True   True       True          False      True      4
# 18     x810    False   True   True       True           True     False      4
# 19     x806    False   True   True       True           True     False      4
# 20      x78    False   True   True       True          False      True      4
# 21     x712    False   True   True       True           True     False      4
# 22     x711    False   True   True       True           True     False      4
# 23     x705    False   True   True       True           True     False      4
# 24     x652    False   True   True       True           True     False      4
# 25     x631    False   True   True       True           True     False      4
# 26     x628    False   True   True       True           True     False      4
# 27     x626    False   True   True       True           True     False      4
# 28     x607    False   True   True       True           True     False      4
# 29       x6    False   True   True       True          False      True      4
# 30     x596    False   True   True       True           True     False      4
# 31     x563    False   True   True       True           True     False      4
# 32     x551    False   True   True       True           True     False      4
# 33     x549    False   True   True       True           True     False      4
# 34      x50    False   True   True       True          False      True      4
# 35     x495    False   True   True       True           True     False      4
# 36     x482    False   True   True       True           True     False      4
# 37     x473     True   True   True      False           True     False      4
# 38     x472    False   True   True       True           True     False      4
# 39     x451    False   True   True       True           True     False      4
# 40     x436    False   True   True       True           True     False      4
# 41     x428    False   True   True       True           True     False      4
# 42     x424    False   True   True       True           True     False      4
# 43     x421    False   True   True       True           True     False      4
# 44     x393    False   True   True       True           True     False      4
# 45     x369    False   True   True       True           True     False      4
# 46     x361    False   True   True       True           True     False      4
# 47     x359    False   True   True       True           True     False      4
# 48      x32    False   True   True       True          False      True      4
# 49       x3    False  False   True       True           True      True      4
# 50     x294    False   True   True       True           True     False      4
# 51     x289     True   True   True      False           True     False      4
# 52     x271    False   True   True       True           True     False      4
# 53     x245    False   True   True       True           True     False      4
# 54     x242    False   True   True       True           True     False      4
# 55     x236    False   True   True       True           True     False      4
# 56     x217    False   True   True       True           True     False      4
# 57       x2    False   True   True       True          False      True      4
# 58     x195    False   True   True       True          False      True      4
# 59     x189    False   True   True       True          False      True      4
# 60     x184     True   True  False      False           True      True      4
# 61     x176    False   True   True       True          False      True      4
# 62     x174    False   True   True       True          False      True      4
# 63     x170     True   True  False      False           True      True      4
# 64     x167    False   True   True       True          False      True      4
# 65     x153    False   True   True       True          False      True      4
# 66     x129     True   True   True      False          False      True      4
# 67     x103    False   True   True       True          False      True      4
# 68       x1    False   True   True       True          False      True      4
# 69      x94    False  False   True      False           True      True      3
# 70      x88    False  False   True       True          False      True      3
# 71     x822    False   True   True       True          False     False      3
# 72     x821    False  False   True       True           True     False      3
# 73      x81     True  False  False      False           True      True      3
# 74     x807    False   True   True       True          False     False      3
# 75      x79    False   True  False       True          False      True      3
# 76     x778    False   True   True       True          False     False      3
# 77     x776     True   True  False      False           True     False      3
# 78      x77    False   True  False       True          False      True      3
# 79     x756    False   True   True       True          False     False      3
# 80     x755    False   True   True       True          False     False      3
# 81     x752    False   True  False       True           True     False      3
# 82     x751    False   True  False       True           True     False      3
# 83     x741    False   True   True       True          False     False      3
# 84     x729    False   True   True       True          False     False      3
# 85     x724    False  False   True       True           True     False      3
# 86     x721    False   True   True       True          False     False      3
# 87     x718    False   True   True       True          False     False      3
# 88     x700    False   True   True       True          False     False      3
# 89      x70    False   True  False       True          False      True      3
# 90     x698    False   True   True       True          False     False      3
# 91     x695    False  False   True       True           True     False      3
# 92     x690     True   True   True      False          False     False      3
# 93     x685     True   True  False      False           True     False      3
# 94     x682    False   True   True       True          False     False      3
# 95     x679    False   True   True       True          False     False      3
# 96     x677    False   True   True       True          False     False      3
# 97     x674    False   True   True       True          False     False      3
# 98     x668    False   True   True       True          False     False      3
# 99     x658    False   True   True       True          False     False      3
# 100    x656    False   True   True       True          False     False      3
# 101    x645    False   True   True       True          False     False      3
# 102    x634    False   True   True       True          False     False      3
# 103    x630    False   True   True       True          False     False      3
# 104    x610    False  False   True       True           True     False      3
# 105    x609    False   True   True       True          False     False      3
# 106    x606    False  False   True       True           True     False      3
# 107    x597     True   True  False      False           True     False      3
# 108    x589    False   True   True       True          False     False      3
# 109    x588    False   True   True       True          False     False      3
# 110    x586    False   True   True       True          False     False      3
# 111    x571    False   True   True       True          False     False      3
# 112    x559     True   True  False      False           True     False      3
# 113    x556    False   True   True       True          False     False      3
# 114    x545     True   True  False      False           True     False      3
# 115    x540     True   True   True      False          False     False      3
# 116    x537     True   True  False      False           True     False      3
# 117    x532    False   True   True       True          False     False      3
# 118    x528    False   True   True       True          False     False      3
# 119    x527    False   True   True       True          False     False      3
# 120    x513    False   True   True       True          False     False      3
# 121    x506    False   True   True       True          False     False      3
# 122    x505    False   True   True       True          False     False      3
# 123    x483    False   True   True       True          False     False      3
# 124     x48    False  False   True       True          False      True      3
# 125    x468    False   True   True       True          False     False      3
# 126    x454    False   True   True       True          False     False      3
# 127    x452    False   True   True       True          False     False      3
# 128    x444    False   True   True       True          False     False      3
# 129    x442    False   True   True       True          False     False      3
# 130    x435    False   True   True       True          False     False      3
# 131    x433    False   True   True       True          False     False      3
# 132    x422    False   True   True       True          False     False      3
# 133     x41     True  False  False      False           True      True      3
# 134    x397    False   True   True       True          False     False      3
# 135    x382    False   True   True       True          False     False      3
# 136    x378    False   True   True       True          False     False      3
# 137    x374    False   True   True       True          False     False      3
# 138    x367    False   True   True       True          False     False      3
# 139    x366    False   True   True       True          False     False      3
# 140    x364    False   True   True       True          False     False      3
# 141    x363    False   True   True       True          False     False      3
# 142     x36    False  False  False       True           True      True      3
# 143    x350    False   True   True       True          False     False      3
# 144    x345    False   True   True       True          False     False      3
# 145    x342    False   True   True       True          False     False      3
# 146    x338    False   True   True       True          False     False      3
# 147    x332    False   True  False       True           True     False      3
# 148    x317    False   True   True       True          False     False      3
# 149    x310    False   True   True       True          False     False      3
# 150     x31    False  False  False       True           True      True      3
# 151    x302     True   True  False      False           True     False      3
# 152    x287    False   True   True       True          False     False      3
# 153    x281    False   True   True       True          False     False      3
# 154    x276    False  False   True       True           True     False      3
# 155    x269    False   True   True       True          False     False      3
# 156    x268    False   True   True       True          False     False      3
# 157    x266    False   True   True       True          False     False      3
# 158    x263    False   True   True       True          False     False      3
# 159    x257    False   True   True       True          False     False      3
# 160    x256    False   True   True       True          False     False      3
# 161    x232    False   True   True       True          False     False      3
# 162    x227     True   True   True      False          False     False      3
# 163    x214     True   True   True      False          False     False      3
# 164    x212    False   True   True       True          False     False      3
# 165    x202    False   True   True       True          False     False      3
# 166    x196     True   True  False      False          False      True      3
# 167    x182    False  False   True       True          False      True      3
# 168    x181    False   True   True      False          False      True      3
# 169    x180     True  False  False      False           True      True      3
# 170    x179    False  False   True       True          False      True      3
# 171    x172    False   True   True      False          False      True      3
# 172    x171     True  False  False      False           True      True      3
# 173    x156    False   True  False       True          False      True      3
# 174     x15    False  False   True       True          False      True      3
# 175    x120    False  False  False       True           True      True      3
# 176    x119    False  False   True       True          False      True      3
# 177    x112    False  False   True      False           True      True      3
# 178     x11    False  False   True       True          False      True      3
# 179     x93     True  False  False      False          False      True      2
# 180     x91    False  False  False      False           True      True      2
# 181    x811    False   True  False       True          False     False      2
# 182    x801    False   True  False       True          False     False      2
# 183    x800     True  False  False      False           True     False      2
# 184     x80     True  False  False      False          False      True      2
# 185      x8    False  False  False      False           True      True      2
# 186    x794    False   True   True      False          False     False      2
# 187    x787    False  False   True      False           True     False      2
# 188    x775     True  False  False      False           True     False      2
# 189    x772     True  False  False      False           True     False      2
# 190    x764     True  False   True      False          False     False      2
# 191    x762    False   True  False       True          False     False      2
# 192    x758    False  False   True       True          False     False      2
# 193     x75     True  False  False      False          False      True      2
# 194    x747    False  False   True       True          False     False      2
# 195    x746    False   True  False       True          False     False      2
# 196    x744    False   True   True      False          False     False      2
# 197     x74     True  False  False      False          False      True      2
# 198    x735    False  False   True       True          False     False      2
# 199    x732    False  False   True      False           True     False      2
# 200    x726     True  False  False      False           True     False      2

# %%
#Creates the csv file with removed features for train data
    
top_features = feature_selection_df.copy()
filtered_X = X.copy()

last_features = top_features.tail(len(top_features)-num_features)

for index, row in last_features.iterrows():
    filtered_X = filtered_X.drop(columns=[row.Feature])

filtered_X.to_csv('x_train_wo_outliers_dataval_200f.csv', index=False)

# %%
#Creates the csv file with removed features for test data
    
top_features = feature_selection_df.copy()
filtered_X_test = X_test.copy()

last_features = top_features.tail(len(top_features)-num_features)

for index, row in last_features.iterrows():
    filtered_X_test = filtered_X_test.drop(columns=[row.Feature])

filtered_X_test.to_csv('x_test_dataval_200f.csv', index=False)
